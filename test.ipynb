# %%
from rfgap import RFGAP
from rfphate import RFPHATE
from dataprep import dataprep

import pandas as pd
import seaborn as sns

# %%
data   = pd.read_csv('./datasets/' + 'titanic' + '.csv', sep = ',')
x, y   = dataprep(data)
n, d   = x.shape
n_classes = len(y.unique())

# %%
rfphate = RFPHATE(y = y, prox_method = 'rfgap', random_state = 0)

# %%
embedding = rfphate.fit_transform(x, y)

# %%
sns.scatterplot(x = embedding[:, 0], y = embedding[:, 1], hue = pd.Categorical(data.iloc[:, 0]))
# Out:
# <Axes: >
