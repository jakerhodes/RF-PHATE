# %% [markdown]
# RF-PHATE is a supervised dimensionality reduction tool which can be used in exploratory data analysis. To install, please use: `pip install git+https://github.com/jakerhodes/RF-PHATE`.

# %%
import rfphate
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# Here we provide a simple example of using RF-PHATE for dimensionality reduction. We use the `titanic` dataset with survival as the response. We use the `dataprep` function to encode categorical variables as numeric and normalize all numeric variables. This function provides us the data, `x` and labels `y`.

# %%
data = rfphate.load_data('titanic')
x, y = rfphate.dataprep(data)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.5, random_state = 42, shuffle=False)

# %% [markdown]
# # Visualize RF-PHATE training embeddings

# %% [markdown]
# We instantiate an RF-PHATE object and generate the 2-dimensional embedding using the `fit_transform` method. The resulting embedding will be stored as a NumPy array. This should take less than a couple of seconds to run.

# %%
rfphate_op = rfphate.RFPHATE(random_state = 42,
                             kernel_method='gap',
                             model_type='rf',
                             verbose=1,
                             allow_semi_supervised=True,
                             force_nonzero_diag=True,
                             force_symmetric=True,
                             kernel_symm = None,
                             self_similarity=False
                             )
emb = rfphate_op.fit_transform(np.vstack([x_train, x_test]), np.concatenate([y_train, -1*np.ones_like(y_test)]))
# Out:
# Calculating PHATE...
#   Running PHATE on precomputed affinity matrix with 712 observations.
#   Calculating graph and diffusion operator...
#   Calculating optimal t...
#     Automatically selected t = 17
#   Calculated optimal t in 0.04 seconds.
#   Calculating diffusion potential...
#   Calculating metric MDS...
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
#     SGD-MDS may not have converged: stress changed by 1.9% in final iterations. Consider increasing n_iter or adjusting learning_rate.
#   Calculated metric MDS in 1.06 seconds.
# Calculated PHATE in 1.11 seconds.

# %% [markdown]
# We can explore variable relationships by coloring the scatterplot of the embedding by different featuers. We start by coloring with the class labels, `'Survived'`

# %%
plot = sns.scatterplot(x = emb[:, 0], y = emb[:, 1], hue = y, markers = {'survived': '.', 'died': 'X'}, style = data['Survived'], alpha = .8)
plot.set(xlabel='RF-PHATE 1', ylabel='RF-PHATE 2')
# Out:
# [Text(0.5, 0, 'RF-PHATE 1'), Text(0, 0.5, 'RF-PHATE 2')]

# %% [markdown]
# To select features for coloration, we can see which features are most important for the prediction problem using the random forests `feature_importances_`

# %%
data.iloc[:, 1:].columns
# Out:
# Index(['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'], dtype='object')

# %%
importances = rfphate_op.kernel_model_.feature_importances_
sorted_indices = importances.argsort()[::-1]
sorted_features = data.iloc[:, 1:].columns[sorted_indices]
sorted_importances = importances[sorted_indices]

sns.barplot(x = sorted_features, y = sorted_importances)
# Out:
# <Axes: xlabel='None'>

# %%
plot = sns.scatterplot(x = emb[:, 0], y = emb[:, 1], hue = data['Fare'], markers = {'survived': '.', 'died': 'X'}, style = data['Survived'], alpha = .8)
plot.legend(title = 'Fare', loc = 'upper right')
plot.set_title('RF-PHATE Embedding Colored by Fare')
plot.set_xlabel('RF-PHATE 1')
plot.set_ylabel('RF-PHATE 2')
# Out:
# Text(0, 0.5, 'RF-PHATE 2')

# %%
plot = sns.scatterplot(x=emb[:, 0], y=emb[:, 1], hue=data['Age'], size=data['Age'], sizes=(10, 100), style=data['Survived'], alpha=.8, markers = {'survived': '.', 'died': 'X'})
plot.legend(title='Age', loc='upper right')
plot.set_title('RF-PHATE Embedding Colored by Age')
plot.set_xlabel('RF-PHATE 1')
plot.set_ylabel('RF-PHATE 2')
# Out:
# Text(0, 0.5, 'RF-PHATE 2')

# %%
plot = sns.scatterplot(x = emb[:, 0], y = emb[:, 1], hue = data['Sex'], markers = {'survived': '.', 'died': 'X'}, style = data['Survived'], alpha = .9, palette = 'coolwarm')
plot.set_title('RF-PHATE Embedding Colored by Sex')
plot.set_xlabel('RF-PHATE 1')
plot.set_ylabel('RF-PHATE 2')
# Out:
# Text(0, 0.5, 'RF-PHATE 2')

# %%
plot = sns.scatterplot(x = emb[:, 0], y = emb[:, 1], hue = pd.Categorical(data['Pclass']), markers = {'survived': '.', 'died': 'X'}, style = data['Survived'], alpha = .8, palette = 'Dark2')
plot.set_title('RF-PHATE Embedding Colored by Pclass')
plot.set_xlabel('RF-PHATE 1')
plot.set_ylabel('RF-PHATE 2')
# Out:
# Text(0, 0.5, 'RF-PHATE 2')

# %% [markdown]
# We can take a closer look using `plotly` for an interactive scatterplot. (You can install `plotly` with `pip install plotly`).

# %%
import plotly.express as px

fig = px.scatter(data, x=emb[:, 0], y=emb[:, 1], color=data['Pclass'].astype(str), symbol=data['Survived'], 
                 symbol_map={'died': 'x', 'survived': 'circle'}, hover_data=['Survived', 'Pclass', 'Sex', 'Age', 'Fare'],
                 height=1000, width=1000)
fig.update_layout(title='RF-PHATE Embedding Colored by Pclass', xaxis_title='RF-PHATE 1', yaxis_title='RF-PHATE 2')
fig.show()

# %% [markdown]
# # Check test embedding behaviour

# %%
emb_extended = rfphate_op.transform(x)
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
plot = sns.scatterplot(x = emb_extended[:, 0], y = emb_extended[:, 1], hue = pd.Categorical(data['Pclass']), markers = {'survived': '.', 'died': 'X'}, style = data['Survived'], alpha = .8, palette = 'Dark2')
plot.set_title('RF-PHATE Embedding Colored by Pclass')
plot.set_xlabel('RF-PHATE 1')
plot.set_ylabel('RF-PHATE 2')
# Out:
# Text(0, 0.5, 'RF-PHATE 2')
